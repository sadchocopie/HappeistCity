# %%
import numpy as np
import pandas as pd

df = pd.read_csv('cities_income.csv', index_col=False, header=0);
df
# Out:
#                      City Mean Income 2016 Mean Income 2015 Mean Income 2014  \
# 0          Birmingham, AL           46,346           44,463           44,447
# 1          Montgomery, AL           63,847           62,201           62,568
# 2           Anchorage, AK          102,500           99,630           98,317
# 3              Juneau, AK          104,005          102,355           97,588
# 4             Phoenix, AZ           69,216           66,345           65,770
# 5              Tucson, AZ           51,035           50,150           50,184
# 6         Little Rock, AR           72,819           71,162           69,979
# 7          Fort Smith, AR           55,054           55,079           57,320
# 8           San Diego, CA           90,685           87,081           86,416
# 9         Los Angeles, CA           85,514           82,941           82,109
# 10         Sacramento, CA           76,827           74,159           73,456
# ...
